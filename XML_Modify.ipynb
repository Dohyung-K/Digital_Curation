# %%
import os
import xml.etree.ElementTree as ET

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
targetDir = r"/content/drive/MyDrive/Colab_Notebooks/Curation/datasets/annotations"

##targetDir에서 .xml파일 이름들 리스트로 가져오기
file_list = os.listdir(targetDir)
xml_list = []
for file in file_list:
    if '.xml' in file:
        xml_list.append(file)


file_list
# Out:
# ['580.xml',
#  '581.xml',
#  '582.xml',
#  '583.xml',
#  '584.xml',
#  '585.xml',
#  '586.xml',
#  '587.xml',
#  '588.xml',
#  '589.xml',
#  '856.xml',
#  '590.xml',
#  '591.xml',
#  '592.xml',
#  '593.xml',
#  '594.xml',
#  '595.xml',
#  '596.xml',
#  '597.xml',
#  '598.xml',
#  '599.xml',
#  '600.xml',
#  '601.xml',
#  '857.xml',
#  '602.xml',
#  '603.xml',
#  '858.xml',
#  '604.xml',
#  '605.xml',
#  '606.xml',
#  '607.xml',
#  '608.xml',
#  '609.xml',
#  '610.xml',
#  '611.xml',
#  '612.xml',
#  '613.xml',
#  '859.xml',
#  '614.xml',
#  '615.xml',
#  '616.xml',
#  '617.xml',
#  '619.xml',
#  '860.xml',
#  '620.xml',
#  '618.xml',
#  '621.xml',
#  '622.xml',
#  '623.xml',
#  '624.xml',
#  '861.xml',
#  '633.xml',
#  '634.xml',
#  '635.xml',
#  '625.xml',
#  '626.xml',
#  '627.xml',
#  '628.xml',
#  '629.xml',
#  '630.xml',
#  '631.xml',
#  '632.xml',
#  '638.xml',
#  '862.xml',
#  '863.xml',
#  '639.xml',
#  '864.xml',
#  '865.xml',
#  '874.xml',
#  '875.xml',
#  '876.xml',
# ...

# %%
targetDir = "/content/drive/MyDrive/Colab_Notebooks/Curation/datasets/annotations"

##targetDir에서 .xml파일 이름들 리스트로 가져오기
file_list = os.listdir(targetDir)

num = 1

file_name=[]
for file in file_list:
  if file.count(".") ==1:
    name = file.split(".")[0]
    file_name.append(name)
  else:
    for k in range(len(file)-1,0,-1):
      if file[k]=='.':
        file_name.append(file[:k])
        break

file_name
# Out:
# ['580',
#  '581',
#  '582',
#  '583',
#  '584',
#  '585',
#  '586',
#  '587',
#  '588',
#  '589',
#  '856',
#  '590',
#  '591',
#  '592',
#  '593',
#  '594',
#  '595',
#  '596',
#  '597',
#  '598',
#  '599',
#  '600',
#  '601',
#  '857',
#  '602',
#  '603',
#  '858',
#  '604',
#  '605',
#  '606',
#  '607',
#  '608',
#  '609',
#  '610',
#  '611',
#  '612',
#  '613',
#  '859',
#  '614',
#  '615',
#  '616',
#  '617',
#  '619',
#  '860',
#  '620',
#  '618',
#  '621',
#  '622',
#  '623',
#  '624',
#  '861',
#  '633',
#  '634',
#  '635',
#  '625',
#  '626',
#  '627',
#  '628',
#  '629',
#  '630',
#  '631',
#  '632',
#  '638',
#  '862',
#  '863',
#  '639',
#  '864',
#  '865',
#  '874',
#  '875',
#  '876',
#  '877',
#  '640',
#  '878',
#  '879',
#  '880',
#  '641',
#  '642',
#  '881',
#  '643',
#  '644',
#  '645',
#  '646',
#  '647',
#  '648',
#  '649',
#  '650',
#  '651',
#  '882',
#  '654',
#  '655',
#  '883',
#  '656',
#  '884',
#  '885',
#  '886',
#  '887',
#  '888',
#  '889',
#  '890',
# ...

# %%
##모든 .xml파일에 대해 수정

for xml_file in xml_list:

  for names in file_name:

    target_path = targetDir + "/" + names + ".xml"
    targetXML = open(target_path, 'rt', encoding='UTF8')

    tree = ET.parse(targetXML)

    root = tree.getroot()

   ##수정할 부분
    target_tag = root.find("path")
    a = targetDir + "\\" + names + ".jpg"
    target_tag = root.find("filename")
    b = file_name
      
    tree.write(file_list)
# Out:
#   File "<string>", line unknown
# ParseError: no element found: line 1, column 0
